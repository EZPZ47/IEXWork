# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd
ecom = pd.read_csv('Ecommerce Purchases')

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom['Purchase Price'].mean()
# Out:
# 50.347302

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom['Purchase Price'].max()
# Out:
# 99.99

# %%
ecom['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
ecom[ecom['Language']=='en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
ecom[ecom['Job']=='Lawyer'].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 470 to 9979
# Data columns (total 14 columns):
# Address             30 non-null object
# Lot                 30 non-null object
# AM or PM            30 non-null object
# Browser Info        30 non-null object
# Company             30 non-null object
# Credit Card         30 non-null int64
# CC Exp Date         30 non-null object
# CC Security Code    30 non-null int64
# CC Provider         30 non-null object
# Email               30 non-null object
# Job                 30 non-null object
# IP Address          30 non-null object
# Language            30 non-null object
# Purchase Price      30 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 3.5+ KB

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
ecom[ecom['AM or PM']=='AM'].count()
# Out:
# Address             4932
# Lot                 4932
# AM or PM            4932
# Browser Info        4932
# Company             4932
# Credit Card         4932
# CC Exp Date         4932
# CC Security Code    4932
# CC Provider         4932
# Email               4932
# Job                 4932
# IP Address          4932
# Language            4932
# Purchase Price      4932
# dtype: int64

# %%
ecom['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
ecom[ecom['AM or PM']=='Lawyer'].count()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
ecom['Job'].value_counts().head(5)
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: count, dtype: int64

# %%
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
ecom[ecom['Lot']=="90 WT"]['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
ecom[ecom['Credit Card']=='4926535242672853']
# Out:
# Empty DataFrame
# Columns: [Address, Lot, AM or PM, Browser Info, Company, Credit Card, CC Exp Date, CC Security Code, CC Provider, Email, Job, IP Address, Language, Purchase Price]
# Index: []

# %%
ecom[ecom['Credit Card']==4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
ecom['CC Provider']=='American Express'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998     True
# 9999    False
# Name: CC Provider, Length: 10000, dtype: bool

# %%
ecom['Purchase Price'] > 95
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Purchase Price, Length: 10000, dtype: bool

# %%
ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price'] > 95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
list('02/25').
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 list('02/25').split(sep='/')
#
# AttributeError: 'list' object has no attribute 'split'

# %%
str(list(ecom['CC Exp Date'])).count('25')
# Out:
# 1033

# %%
CC = list(ecom['CC Exp Date'])

# %%
def num(listinput):
    str(list

# %%
type(str(ecom['CC Exp Date']))
# Out:
# str

# %%
str(ecom['CC Exp Date']).split(sep='/')
# Out:
# ['0       02',
#  '20\n1       11',
#  '18\n2       08',
#  '19\n3       02',
#  '24\n4       10',
#  '25\n        ...  \n9995    03',
#  '22\n9996    07',
#  '25\n9997    05',
#  '21\n9998    11',
#  '17\n9999    02',
#  '19\nName: CC Exp Date, Length: 10000, dtype: object']

# %%
ecom['CC Exp Date'].iloc[0][3:]
# Out:
# '20'

# %%
sum(ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25'))
# Out:
# 1033

# %%
ecom[ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25')].count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# dtype: int64

# %%
ecom['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
str(list(ecom['CC Exp Date'])).count('25')
# Out:
# 1033

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
example_email = ecom['Email'].iloc[0]
example_email
# Out:
# 'pdunlap@yahoo.com'

# %%
example_email.split('@')[1]
# Out:
# 'yahoo.com'

# %%
ecom['Email'].apply(lambda exp: exp.split('@')[1]).value_counts().head(5)
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
df = ecom['Email'].apply(lambda exp: exp.split('@')[1])
# Out:
# 0               yahoo.com
# 1                reed.com
# 2    morales-harrison.com
# 3     olson-robinson.info
# 4               gmail.com
# Name: Email, dtype: object

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
list(ecom['Email']).split(sep='@')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[242], line 1
# ----> 1 list(ecom['Email']).split(sep='@')
#
# AttributeError: 'list' object has no attribute 'split'

# %%
str(list(ecom['Email'])).split(sep='@')
# Out:
# ["['pdunlap",
#  "yahoo.com', 'anthony41",
#  "reed.com', 'amymiller",
#  "morales-harrison.com', 'brent16",
#  "olson-robinson.info', 'christopherwright",
#  "gmail.com', 'ynguyen",
#  "gmail.com', 'olivia04",
#  "yahoo.com', 'phillip48",
#  "parks.info', 'kdavis",
#  "rasmussen.com', 'qcoleman",
#  "hunt-huerta.com', 'ustewart",
#  "hotmail.com', 'johnnymiller",
#  "coleman.com', 'tholt",
#  "hotmail.com', 'caitlin57",
#  "yahoo.com', 'aburns",
#  "yahoo.com', 'amanda39",
#  "yahoo.com', 'griffincatherine",
#  "wilson.com', 'stacymitchell",
#  "hall.com', 'hannah63",
#  "yahoo.com', 'ruiznicole",
#  "gmail.com', 'zstephenson",
#  "smith.info', 'rsmith",
#  "hotmail.com', 'chambersmichael",
#  "gmail.com', 'ltaylor",
#  "gardner-meadows.com', 'james07",
#  "yahoo.com', 'madison41",
#  "mooney.com', 'mlogan",
#  "gmail.com', 'michael35",
#  "hotmail.com', 'khandeborah",
#  "yahoo.com', 'stonekaren",
#  "yahoo.com', 'laurahess",
#  "hotmail.com', 'ashley12",
# ...

# %%
df = pd.DataFrame(str(list(ecom['Email'])).split(sep='@'))

# %%
df
# Out:
#                                               0
# 0                                     ['pdunlap
# 1                        yahoo.com', 'anthony41
# 2                         reed.com', 'amymiller
# 3               morales-harrison.com', 'brent16
# 4      olson-robinson.info', 'christopherwright
# ...                                         ...
# 9996                  wade-garner.com', 'mary85
# 9997                     hotmail.com', 'tyler16
# 9998                gmail.com', 'elizabethmoore
# 9999                     reid.net', 'rachelford
# 10000                              vaughn.com']
#
# [10001 rows x 1 columns]

# %%
ecom['Email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# # Great Job!
